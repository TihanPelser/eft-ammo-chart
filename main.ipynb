# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

# %%
eft_df = pd.read_csv('./data/Escape from Tarkov official and actual ammo table - 0.13.5 Patch.csv')
eft_df = eft_df.rename(columns={"0.13.5 Patch": "Calibre"})

# %%
display(eft_df)
# Out:
#     0.13.5 Patch            Ammo  Weight (KG)  Rub price  Damage  Penetration  \
# 0        .45 ACP             FMJ        0.015       83.0    72.0         25.0
# 1        .45 ACP              AP        0.015      725.0    66.0         38.0
# 2        .45 ACP      Hydra-Shok        0.017       99.0   100.0         13.0
# 3        .45 ACP  Lasermatch FMJ        0.015       87.0    76.0         19.0
# 4        .45 ACP             RIP        0.019      401.0   130.0          3.0
# ..           ...             ...          ...        ...     ...          ...
# 182     9x39 mm            BP gs        0.023     1510.0    60.0         55.0
# 183     9x39 mm         PAB-9 gs        0.024     1345.0    62.0         48.0
# 184     9x39 mm          SP-5 gs        0.023      160.0    71.0         28.0
# 185     9x39 mm          SP-6 gs        0.023     1151.0    58.0         46.0
# 186     9x39 mm           SPP gs        0.023      742.0    68.0         40.0
#
#      Armor Damage (%)  Accuracy (%)  Recoil (%)  Projectile Count  \
# 0                36.0           0.0         0.0               1.0
# 1                48.0          -5.0         7.0               1.0
# 2                30.0           0.0         0.0               1.0
# 3                37.0          10.0         0.0               1.0
# 4                12.0          -5.0         0.0               1.0
# ..                ...           ...         ...               ...
# 182              68.0          10.0        22.0               1.0
# 183              72.0         -15.0        10.0               1.0
# 184              60.0           0.0        -5.0               1.0
# 185              60.0           0.0        10.0               1.0
# 186              55.0          10.0        10.0               1.0
#
#      Projectile Speed (m/s)  Penetration Chance  Ricochet Chance  \
# 0                     340.0                0.16            0.065
# 1                     299.0                0.29            0.100
# 2                     274.0                0.13            0.065
# 3                     290.0                0.16            0.065
# 4                     293.0                0.02            0.002
# ..                      ...                 ...              ...
# 182                   295.0                0.75            0.500
# 183                   320.0                0.78            0.480
# 184                   290.0                0.60            0.400
# 185                   305.0                0.70            0.500
# 186                   310.0                0.60            0.400
#
#      Fragmentation Chance HeatFactor DurabilityBurnModificator  \
# 0                    0.01     99.63%                        0%
# 1                    0.01    123.00%                       70%
# 2                    0.50    113.78%                       10%
# 3                    0.01    110.70%                       20%
# 4                    1.00    116.85%                       50%
# ..                    ...        ...                       ...
# 182                  0.10    161.00%                       35%
# 183                  0.10    156.00%                       55%
# 184                  0.20    153.00%                       20%
# 185                  0.10    161.00%                       45%
# 186                  0.20    145.00%                       10%
#
#     Light bleed chance Heavy bleed chance
# 0                   0%                 0%
# 1                   0%                 0%
# 2                   0%                30%
# 3                   0%                 0%
# 4                  30%                20%
# ..                 ...                ...
# 182                 0%                 0%
# 183                10%                12%
# 184                 0%                10%
# 185                10%                10%
# 186                10%                20%
#
# [187 rows x 18 columns]
